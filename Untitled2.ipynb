# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahshona/DS-medicine-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

k = [1, 2]
x = np.linspace(0, 10, 21)
y = np.cos(x)
plt.plot(x, np.cos(k[0])* y)
plt.plot(x, np.cos(k[1])* y)
